# %%
import os
import pandas as pd
import seaborn as sns
# %cd ..
from src.data.dataset import load_kaggle_data
# Out:
# d:\Projects\my-ds-template

# %% [markdown]
# Prepare datasets for further analysis/modeling.
# Example based on 3 tables of characters information from the video game Genshin Impact.

# %% [markdown]
# ## 1. Loading data
# - Retrieving (a subset of) rows
# - Sorting
# - Testing equality, monotonicity
# - Column operations

# %%
dataset_path = 'https://www.kaggle.com/datasets/genshinplayer/genshin-impact-characters-stats'
path, files = load_kaggle_data(dataset_path)
df1 = pd.read_csv(os.path.join(path,files[0])) # skiprows, nrows, header
df1[df1.Character=='Amber']
# Out:
# Skipping, found downloaded files in "../data/raw/genshin-impact-characters-stats" (use force=True to force download)
#    Character  Lv  Rarity Element Weapon Main role Ascension  Base HP  \
# 0      Amber   1       4    Pyro    Bow   Sub DPS       ATK      793
# 1      Amber  20       4    Pyro    Bow   Sub DPS       ATK     2038
# 2      Amber  20       4    Pyro    Bow   Sub DPS       ATK     2630
# 3      Amber  40       4    Pyro    Bow   Sub DPS       ATK     3940
# 4      Amber  40       4    Pyro    Bow   Sub DPS       ATK     4361
# 5      Amber  50       4    Pyro    Bow   Sub DPS       ATK     5016
# 6      Amber  50       4    Pyro    Bow   Sub DPS       ATK     5578
# 7      Amber  60       4    Pyro    Bow   Sub DPS       ATK     6233
# 8      Amber  60       4    Pyro    Bow   Sub DPS       ATK     6654
# 9      Amber  70       4    Pyro    Bow   Sub DPS       ATK     7309
# 10     Amber  70       4    Pyro    Bow   Sub DPS       ATK     7730
# 11     Amber  80       4    Pyro    Bow   Sub DPS       ATK     8385
# 12     Amber  80       4    Pyro    Bow   Sub DPS       ATK     8806
# 13     Amber  90       4    Pyro    Bow   Sub DPS       ATK     9461
#
#     Base ATK  Base DEF
# 0         19        50
# 1         48       129
# 2         62       167
# 3         93       250
# 4        103       277
# 5        118       318
# 6        131       354
# 7        147       396
# 8        157       422
# 9        172       464
# 10       182       491
# 11       198       532
# 12       208       559
# 13       223       601

# %% [markdown]
# This table contains information of each Character from Lv1 to Lv80.
# For each level from Lv20 to Lv 80, there are 2 rows with different HP, ATK & DEF, assumed before/after Ascension.

# %%
# Test Character has identical levels
from pandas import testing as tm
for char, c_df in df1.groupby('Character'):
    # Verify that Lv column for each Character is the same
    tm.assert_series_equal(c_df['Lv'], df1.head(14)['Lv'], check_index=False)
    # Verify that the order of the rows is always before Ascension -> after Ascension
    assert c_df['Base HP'].is_monotonic_increasing==True

# %% [markdown]
# No AssertionError, assumption verified.
# If the rows were not in order, use .sort_values().reset_index(drop=True).

# %%
# Sample all rows from df1 will disrupt the order
# .sort_values method supports multiple columns
# it will sort values according to the first column
# if there are identical values, then refer to the next column.
df1.sample(len(df1)).sort_values(by=['Base ATK','Character']).reset_index(drop=True)
# Out:
#     Character  Lv  Rarity  Element    Weapon Main role        Ascension  \
# 0       Hutao   1       5     Pyro   Polearm       DPS         CRIT DMG
# 1     Barbara   1       4    Hydro  Catalyst    Healer               HP
# 2     Sucrose   1       4    Anemo  Catalyst   Support        Anemo DMG
# 3     Bennett   1       4     Pyro     Sword    Healer  Energy Recharge
# 4      Noelle   1       4      Geo  Claymore   Support              DEF
# ..        ...  ..     ...      ...       ...       ...              ...
# 569     Ganyu  90       5     Cryo       Bow       DPS         CRIT DMG
# 570    Shogun  90       5  Electro   Polearm   Sub DPS  Energy Recharge
# 571     Ayaka  90       5     Cryo     Sword       DPS         CRIT DMG
# 572      Eula  90       5     Cryo  Claymore       DPS         CRIT DMG
# 573      Xiao  90       5    Anemo   Polearm       DPS        CRIT Rate
#
#      Base HP  Base ATK  Base DEF
# 0       1211         8        68
# 1        821        13        56
# 2        775        14        59
# 3       1039        16        65
# 4       1012        16        67
# ..       ...       ...       ...
# 569     9797       335       630
# 570    12907       337       789
# 571    12858       342       784
# 572    13226       342       751
# 573    12736       349       799
#
# [574 rows x 10 columns]

# %%
# Rename columns. Good names are important!
df1 = df1.rename({'Ascension':'Ascension Stat'},axis=1)
# Create a new column representing whether it is before or after Ascension
df1['Ascension'] = len(set(df1.Character))*([pd.NA]+[0,1]*6+[pd.NA])
df1.head(5)
# Out:
#   Character  Lv  Rarity Element Weapon Main role Ascension Stat  Base HP  \
# 0     Amber   1       4    Pyro    Bow   Sub DPS            ATK      793
# 1     Amber  20       4    Pyro    Bow   Sub DPS            ATK     2038
# 2     Amber  20       4    Pyro    Bow   Sub DPS            ATK     2630
# 3     Amber  40       4    Pyro    Bow   Sub DPS            ATK     3940
# 4     Amber  40       4    Pyro    Bow   Sub DPS            ATK     4361
#
#    Base ATK  Base DEF Ascension
# 0        19        50      <NA>
# 1        48       129         0
# 2        62       167         1
# 3        93       250         0
# 4       103       277         1

# %%
# Second data source include additional information on Region and Model Type
url= 'https://genshin-impact.fandom.com/wiki/Characters'
df2 = pd.read_html(url)[2]
df2 = df2.drop(columns=['Icon','Rarity'])
df2 = df2.rename({'Name':'Character'},
                 axis=1)
df2.sample(3)  #  head, tail
# Out:
#    Character  Element    Weapon     Region     Model Type
# 11    Fischl  Electro       Bow  Mondstadt  Medium Female
# 15      Jean    Anemo     Sword  Mondstadt    Tall Female
# 27    Noelle      Geo  Claymore  Mondstadt  Medium Female

# %%
# Third data source include stats of more Characters at Lv90
url= 'https://genshin-impact.fandom.com/wiki/Characters/Comparison'
df3 = pd.read_html(url)[1]
df3 = df3.drop(columns=['Icon'])
df3.rename(columns={'Name':'Character',
                    'HP': 'Base HP',
                    'ATK': 'Base ATK',
                    'DEF': 'Base DEF',
                    }, 
           inplace=True)
df3.head(4)
# Out:
#       Character  Base HP  Base ATK  Base DEF  Ascension Stat  \
# 0        Albedo    13226       251       876   Geo DMG Bonus
# 1          Aloy    10899       234       676  Cryo DMG Bonus
# 2         Amber     9461       223       601             ATK
# 3  Arataki Itto    12858       227       959       CRIT Rate
#
#   Ascension Stat Value
# 0                28.8%
# 1                28.8%
# 2                24.0%
# 3                19.2%

# %% [markdown]
# ## 2. Working with multiple tables
# - String processing
# - Union, Intersection, Difference, Symmetric Difference
# - Merge (Join) multiple tables
#     Here's a [helpful question on Stack Overflow](https://stackoverflow.com/questions/53645882/pandas-merging-101/53645883#53645883).

# %% [markdown]
# To merge `df1` and `df2`, we need to create an unique key to match the rows to the characters.

# %%
# Table 1: 
# Only first name for japanese names
df1.Character.unique()
# Out:
# array(['Amber', 'Barbara', 'Beidou', 'Bennett', 'Chongyun', 'Diluc',
#        'Fischl', 'Jean', 'Kaeya', 'Keqing', 'Klee', 'Lisa', 'Mona',
#        'Ningguang', 'Noelle', 'Qiqi', 'Razor', 'Sucrose', 'Venti',
#        'Xiangling', 'Xiao', 'Xingqiu', 'Tartaglia', 'Zhongli', 'Diona',
#        'Xinyan', 'Ganyu', 'Albedo', 'Rosaria', 'Ayaka', 'Hutao', 'Yanfei',
#        'Eula', 'Kazuha', 'Yoimiya', 'Sayu', 'Traveler', 'Shogun', 'Aloy',
#        'Sara', 'Kokomi'], dtype=object)

# %%
# Table 2&3 have identical Characters
assert (df3.Character.unique() == df2.Character.unique()).all()
df3.Character.unique()
# Out:
# array(['Albedo', 'Aloy', 'Amber', 'Arataki Itto', 'Barbara', 'Beidou',
#        'Bennett', 'Chongyun', 'Diluc', 'Diona', 'Eula', 'Fischl', 'Ganyu',
#        'Gorou', 'Hu Tao', 'Jean', 'Kaedehara Kazuha', 'Kaeya',
#        'Kamisato Ayaka', 'Kamisato Ayato', 'Keqing', 'Klee', 'Kujou Sara',
#        'Kuki Shinobu', 'Lisa', 'Mona', 'Ningguang', 'Noelle', 'Qiqi',
#        'Raiden Shogun', 'Razor', 'Rosaria', 'Sangonomiya Kokomi', 'Sayu',
#        'Shenhe', 'Shikanoin Heizou', 'Sucrose', 'Tartaglia', 'Thoma',
#        'Traveler', 'Venti', 'Xiangling', 'Xiao', 'Xingqiu', 'Xinyan',
#        'Yae Miko', 'Yanfei', 'Yelan', 'Yoimiya', 'Yun Jin', 'Zhongli'],
#       dtype=object)

# %% [markdown]
# We can use the lowercase of the full names without spaces as ID.

# %%
# Create unique IDs for characters based on their full names in table 2
df2['ID'] = df2['Character'].transform(lambda x: x.replace(' ','').lower())
df3['ID'] = df3['Character'].transform(lambda x: x.replace(' ','').lower())

# Assign ID to characters in table 1
def get_id(x, id_list):
    for id in id_list:
        if x.lower() in id:
            return id
    return x
df1['ID'] = df1['Character'].apply(lambda x: get_id(x, df2['ID'].unique()))

# %%
# Intersection, Difference, Union of sets
len(set(df2.ID)|set(df1.ID)) # &, -, |
# Out:
# 51

# %%
# All ID in df1 can be found in df2
set(df1.ID) - set(df2.ID)
# Out:
# set()

# %%
set(df2.columns) & set(df1.columns)
# Out:
# {'Character', 'Element', 'ID', 'Weapon'}

# %% [markdown]
# Before we merge everything together, IMO there is a clear difference of potential use between a table with only lv90 data and a table with data from lv1 to lv90. So I will separately store them.

# %%
df2['ID'] = df2['Character'].transform(lambda x: x.replace(' ','').lower())
columns_from_df2 = ['ID']+list(set(df2.columns) - set(df1.columns))
df_growth = pd.merge(df1, df2[columns_from_df2], on='ID', how='left')
df_growth = df_growth.set_index('ID').reset_index()
df_growth
# Out:
#                     ID Character  Lv  Rarity Element    Weapon Main role  \
# 0                amber     Amber   1       4    Pyro       Bow   Sub DPS
# 1                amber     Amber  20       4    Pyro       Bow   Sub DPS
# 2                amber     Amber  20       4    Pyro       Bow   Sub DPS
# 3                amber     Amber  40       4    Pyro       Bow   Sub DPS
# 4                amber     Amber  40       4    Pyro       Bow   Sub DPS
# ..                 ...       ...  ..     ...     ...       ...       ...
# 569  sangonomiyakokomi    Kokomi  70       5   Hydro  Catalyst    Healer
# 570  sangonomiyakokomi    Kokomi  70       5   Hydro  Catalyst    Healer
# 571  sangonomiyakokomi    Kokomi  80       5   Hydro  Catalyst    Healer
# 572  sangonomiyakokomi    Kokomi  80       5   Hydro  Catalyst    Healer
# 573  sangonomiyakokomi    Kokomi  90       5   Hydro  Catalyst    Healer
#
#     Ascension Stat  Base HP  Base ATK  Base DEF Ascension     Model Type  \
# 0              ATK      793        19        50      <NA>  Medium Female
# 1              ATK     2038        48       129         0  Medium Female
# 2              ATK     2630        62       167         1  Medium Female
# 3              ATK     3940        93       250         0  Medium Female
# 4              ATK     4361       103       277         1  Medium Female
# ..             ...      ...       ...       ...       ...            ...
# 569      Hydro DMG    10306       179       503         0  Medium Female
# 570      Hydro DMG    10945       190       534         1  Medium Female
# 571      Hydro DMG    11885       207       580         0  Medium Female
# 572      Hydro DMG    12524       218       611         1  Medium Female
# 573      Hydro DMG    13471       234       657      <NA>  Medium Female
#
#         Region
# 0    Mondstadt
# 1    Mondstadt
# 2    Mondstadt
# 3    Mondstadt
# 4    Mondstadt
# ..         ...
# 569    Inazuma
# 570    Inazuma
# 571    Inazuma
# 572    Inazuma
# 573    Inazuma
#
# [574 rows x 14 columns]

# %%
df_lv_90 = df3
columns_from_df2 = ['ID']+list(set(df2.columns) - set(df3.columns))
df_lv_90 = pd.merge(df3, df2[columns_from_df2], on='ID', how='left')
df_lv_90 = df_lv_90.set_index('ID').reset_index()
df_lv_90
# Out:
#                    ID           Character  Base HP  Base ATK  Base DEF  \
# 0              albedo              Albedo    13226       251       876
# 1                aloy                Aloy    10899       234       676
# 2               amber               Amber     9461       223       601
# 3         aratakiitto        Arataki Itto    12858       227       959
# 4             barbara             Barbara     9787       159       669
# 5              beidou              Beidou    13050       225       648
# 6             bennett             Bennett    12397       191       771
# 7            chongyun            Chongyun    10984       223       648
# 8               diluc               Diluc    12981       335       784
# 9               diona               Diona     9570       212       601
# 10               eula                Eula    13226       342       751
# 11             fischl              Fischl     9189       244       594
# 12              ganyu               Ganyu     9797       335       630
# 13              gorou               Gorou     9570       183       648
# 14              hutao              Hu Tao    15552       106       876
# 15               jean                Jean    14695       239       769
# 16    kaedeharakazuha    Kaedehara Kazuha    13348       297       807
# 17              kaeya               Kaeya    11636       223       792
# 18      kamisatoayaka      Kamisato Ayaka    12858       342       784
# 19      kamisatoayato      Kamisato Ayato    13715       299       769
# 20             keqing              Keqing    13103       323       799
# 21               klee                Klee    10287       311       615
# 22          kujousara          Kujou Sara     9570       195       628
# 23        kukishinobu        Kuki Shinobu    12289       212       751
# 24               lisa                Lisa     9570       232       573
# 25               mona                Mona    10409       287       653
# 26          ningguang           Ningguang     9787       212       573
# 27             noelle              Noelle    12071       191       799
# 28               qiqi                Qiqi    12368       287       922
# 29       raidenshogun       Raiden Shogun    12907       337       789
# 30              razor               Razor    11962       234       751
# 31            rosaria             Rosaria    12289       240       710
# 32  sangonomiyakokomi  Sangonomiya Kokomi    13471       234       657
# 33               sayu                Sayu    11854       244       745
# 34             shenhe              Shenhe    12993       304       830
# 35    shikanoinheizou    Shikanoin Heizou    10657       225       684
# 36            sucrose             Sucrose     9243       170       703
# 37          tartaglia           Tartaglia    13103       301       815
# 38              thoma               Thoma    10331       202       751
# 39           traveler            Traveler    10875       212       683
# 40              venti               Venti    10531       263       669
# 41          xiangling           Xiangling    10875       225       669
# 42               xiao                Xiao    12736       349       799
# 43            xingqiu             Xingqiu    10223       202       758
# 44             xinyan              Xinyan    11201       249       799
# 45            yaemiko            Yae Miko    10372       340       569
# 46             yanfei              Yanfei     9352       240       587
# 47              yelan               Yelan    14450       244       548
# 48            yoimiya             Yoimiya    10164       323       615
# 49             yunjin             Yun Jin    10657       191       734
# 50            zhongli             Zhongli    14695       251       738
#
#         Ascension Stat Ascension Stat Value  Element    Weapon  \
# 0        Geo DMG Bonus                28.8%      Geo     Sword
# 1       Cryo DMG Bonus                28.8%     Cryo       Bow
# 2                  ATK                24.0%     Pyro       Bow
# 3            CRIT Rate                19.2%      Geo  Claymore
# 4                   HP                24.0%    Hydro  Catalyst
# 5    Electro DMG Bonus                24.0%  Electro  Claymore
# 6      Energy Recharge                26.7%     Pyro     Sword
# 7                  ATK                24.0%     Cryo  Claymore
# 8            CRIT Rate                19.2%     Pyro  Claymore
# 9       Cryo DMG Bonus                24.0%     Cryo       Bow
# 10            CRIT DMG                38.4%     Cryo  Claymore
# 11                 ATK                24.0%  Electro       Bow
# 12            CRIT DMG                38.4%     Cryo       Bow
# 13       Geo DMG Bonus                24.0%      Geo       Bow
# 14            CRIT DMG                38.4%     Pyro   Polearm
# 15       Healing Bonus                22.2%    Anemo     Sword
# 16   Elemental Mastery                115.2    Anemo     Sword
# 17     Energy Recharge                26.7%     Cryo     Sword
# 18            CRIT DMG                38.4%     Cryo     Sword
# 19            CRIT DMG                38.4%    Hydro     Sword
# 20            CRIT DMG                38.4%  Electro     Sword
# 21      Pyro DMG Bonus                28.8%     Pyro  Catalyst
# 22                 ATK                24.0%  Electro       Bow
# 23                  HP                24.0%  Electro     Sword
# 24   Elemental Mastery                   96  Electro  Catalyst
# 25     Energy Recharge                32.0%    Hydro  Catalyst
# 26       Geo DMG Bonus                24.0%      Geo  Catalyst
# 27                 DEF                30.0%      Geo  Claymore
# 28       Healing Bonus                22.2%     Cryo     Sword
# 29     Energy Recharge                32.0%  Electro   Polearm
# 30  Physical DMG Bonus                30.0%  Electro  Claymore
# 31                 ATK                24.0%     Cryo   Polearm
# 32     Hydro DMG Bonus                28.8%    Hydro  Catalyst
# 33   Elemental Mastery                   96    Anemo  Claymore
# 34                 ATK                28.8%     Cryo   Polearm
# 35     Anemo DMG Bonus                24.0%    Anemo  Catalyst
# 36     Anemo DMG Bonus                24.0%    Anemo  Catalyst
# 37     Hydro DMG Bonus                28.8%    Hydro       Bow
# 38                 ATK                24.0%     Pyro   Polearm
# 39                 ATK                24.0%     None     Sword
# 40     Energy Recharge                32.0%    Anemo       Bow
# 41   Elemental Mastery                   96     Pyro   Polearm
# 42           CRIT Rate                19.2%    Anemo   Polearm
# 43                 ATK                24.0%    Hydro     Sword
# 44                 ATK                24.0%     Pyro  Claymore
# 45           CRIT Rate                19.2%  Electro  Catalyst
# 46      Pyro DMG Bonus                24.0%     Pyro  Catalyst
# 47           CRIT Rate                19.2%    Hydro       Bow
# 48           CRIT Rate                19.2%     Pyro       Bow
# 49     Energy Recharge                26.7%      Geo   Polearm
# 50       Geo DMG Bonus                28.8%      Geo   Polearm
#
#                                   Model Type     Region
# 0                                Medium Male  Mondstadt
# 1                              Medium Female        NaN
# 2                              Medium Female  Mondstadt
# 3                                  Tall Male    Inazuma
# 4                              Medium Female  Mondstadt
# 5                                Tall Female      Liyue
# 6                                Medium Male  Mondstadt
# 7                                Medium Male      Liyue
# 8                                  Tall Male  Mondstadt
# 9                               Short Female  Mondstadt
# 10                               Tall Female  Mondstadt
# 11                             Medium Female  Mondstadt
# 12                             Medium Female      Liyue
# 13                               Medium Male    Inazuma
# 14                             Medium Female      Liyue
# 15                               Tall Female  Mondstadt
# 16                               Medium Male    Inazuma
# 17                                 Tall Male  Mondstadt
# 18                             Medium Female    Inazuma
# 19                                 Tall Male    Inazuma
# 20                             Medium Female      Liyue
# 21                              Short Female  Mondstadt
# 22                               Tall Female    Inazuma
# 23                             Medium Female    Inazuma
# 24                               Tall Female  Mondstadt
# 25                             Medium Female  Mondstadt
# 26                               Tall Female      Liyue
# 27                             Medium Female  Mondstadt
# 28                              Short Female      Liyue
# 29                               Tall Female    Inazuma
# 30                               Medium Male  Mondstadt
# 31                               Tall Female  Mondstadt
# 32                             Medium Female    Inazuma
# 33                              Short Female    Inazuma
# 34                               Tall Female      Liyue
# 35                               Medium Male    Inazuma
# 36                             Medium Female  Mondstadt
# 37                                 Tall Male  Snezhnaya
# 38                                 Tall Male    Inazuma
# 39  Aether: Medium MaleLumine: Medium Female        NaN
# 40                               Medium Male  Mondstadt
# 41                             Medium Female      Liyue
# 42                               Medium Male      Liyue
# 43                               Medium Male      Liyue
# 44                             Medium Female      Liyue
# 45                               Tall Female    Inazuma
# 46                             Medium Female      Liyue
# 47                               Tall Female      Liyue
# 48                             Medium Female    Inazuma
# 49                             Medium Female      Liyue
# 50                                 Tall Male      Liyue

# %% [markdown]
# ## 3. Update data
# - Check & fill missing values (na/null)
# - Update cells according to index and label

# %%
# Find mismatched values
columns = ['ID','Base HP','Base ATK','Base DEF']

hp_df1 = df_lv_90[columns].copy()
hp_df1['tabel'] = 'lv 90'

hp_df3 = df_growth[df_growth.Lv==90][columns].copy()
hp_df3['tabel'] = 'growth'

pd.concat([hp_df1, hp_df3], axis=0).drop_duplicates(subset=columns, keep=False).sort_values('ID')
# Out:
#                   ID  Base HP  Base ATK  Base DEF   tabel
# 3        aratakiitto    12858       227       959   lv 90
# 13             gorou     9570       183       648   lv 90
# 19     kamisatoayato    13715       299       769   lv 90
# 23       kukishinobu    12289       212       751   lv 90
# 34            shenhe    12993       304       830   lv 90
# 35   shikanoinheizou    10657       225       684   lv 90
# 36           sucrose     9243       170       703   lv 90
# 251          sucrose     9244       170       703  growth
# 38             thoma    10331       202       751   lv 90
# 43           xingqiu    10223       202       758   lv 90
# 307          xingqiu    10222       202       758  growth
# 45           yaemiko    10372       340       569   lv 90
# 47             yelan    14450       244       548   lv 90
# 49            yunjin    10657       191       734   lv 90

# %%
df_growth.isna().sum()
# Out:
# ID                 0
# Character          0
# Lv                 0
# Rarity             0
# Element            0
# Weapon             0
# Main role          0
# Ascension Stat     0
# Base HP            0
# Base ATK           0
# Base DEF           0
# Ascension         82
# Model Type         0
# Region            28
# dtype: int64

# %%
df_lv_90.isna().sum()
# Out:
# ID                      0
# Character               0
# Base HP                 0
# Base ATK                0
# Base DEF                0
# Ascension Stat          0
# Ascension Stat Value    0
# Element                 0
# Weapon                  0
# Model Type              0
# Region                  2
# dtype: int64

# %%
df_lv_90[df_lv_90.Region.isna()]
# Out:
#           ID Character  Base HP  Base ATK  Base DEF  Ascension Stat  \
# 1       aloy      Aloy    10899       234       676  Cryo DMG Bonus
# 39  traveler  Traveler    10875       212       683             ATK
#
#    Ascension Stat Value Element Weapon  \
# 1                 28.8%    Cryo    Bow
# 39                24.0%    None  Sword
#
#                                   Model Type Region
# 1                              Medium Female    NaN
# 39  Aether: Medium MaleLumine: Medium Female    NaN

# %%
# Sometimes, if we have to, we can update values manually.
# Difference between loc & iloc see https://stackoverflow.com/questions/31593201/how-are-iloc-and-loc-different
df_lv_90.loc[[1,39], ['Region']] = [['Unknow'], ['Nora']]
df_lv_90.iloc[[1,39]]
# Out:
#           ID Character  Base HP  Base ATK  Base DEF  Ascension Stat  \
# 1       aloy      Aloy    10899       234       676  Cryo DMG Bonus
# 39  traveler  Traveler    10875       212       683             ATK
#
#    Ascension Stat Value Element Weapon  \
# 1                 28.8%    Cryo    Bow
# 39                24.0%    None  Sword
#
#                                   Model Type  Region
# 1                              Medium Female  Unknow
# 39  Aether: Medium MaleLumine: Medium Female    Nora

# %%
df_growth[df_growth['ID']=='albedo'].head(1)[['Rarity','Main role']].values
# Out:
# array([[5, 'Support']], dtype=object)

# %%
df_lv_90[['Rarity','Main role']] = df_lv_90.apply(lambda row: df_growth[df_growth['ID']==row['ID']].head(1)[['Rarity','Main role']].values.flatten() if row['ID'] in df_growth.ID.unique() else pd.NA*2, result_type='expand', axis=1)

# %%
df_growth.to_csv('data/processed/genshin_character_growth.csv', index=False)
df_lv_90.to_csv('data/processed/genshin_character_lv_90.csv', index=False)

# %% [markdown]
# ## Checklist
# - Assumptions
#   1. Names in df1 are substrings from df2 after removing spaces and lowercaseization.
# - Missing values
#   - Traveler and Aloe don't have Region label.
#   - Lv1 and Lv90 rows don't have Ascension label.

# %%
# query detailed information for each character on fandom.com
url= 'https://genshin-impact.fandom.com/wiki/Razor'
df = pd.read_html(url)[2]
df.head(3)
# Out:
#                                       AscensionPhase  \
# 0                                                 0✦
# 1                                                 0✦
# 2  Ascension Cost (0 → 1)20,000 20,000 Mora1 1 Va...
#
#                                                Level  \
# 0                                               1/20
# 1                                              20/20
# 2  Ascension Cost (0 → 1)20,000 20,000 Mora1 1 Va...
#
#                                               BaseHP  \
# 0                                               1003
# 1                                               2577
# 2  Ascension Cost (0 → 1)20,000 20,000 Mora1 1 Va...
#
#                                             BaseATK1  \
# 0                                                 20
# 1                                                 50
# 2  Ascension Cost (0 → 1)20,000 20,000 Mora1 1 Va...
#
#                                              BaseDEF  \
# 0                                                 63
# 1                                                162
# 2  Ascension Cost (0 → 1)20,000 20,000 Mora1 1 Va...
#
#                    Special Stat2(Physical DMG Bonus)
# 0                                                  —
# 1                                                  —
# 2  Ascension Cost (0 → 1)20,000 20,000 Mora1 1 Va...
