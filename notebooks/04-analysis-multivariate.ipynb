# %%
import os
import pandas as pd
import seaborn as sns

# %cd ..
# Out:
# d:\Projects\my-ds-template

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# %% [markdown]
# ## Assumption

# %% [markdown]
# ## Simple Linear Regression

# %%
df_growth = pd.read_csv('data/processed/genshin_character_growth.csv')
df_growth.sample(5)
# Out:
#             ID  Character  Lv  Rarity Element    Weapon Main role  \
# 187  ningguang  Ningguang  50       4     Geo  Catalyst       DPS
# 453       eula       Eula  50       5    Cryo  Claymore       DPS
# 182  ningguang  Ningguang   1       4     Geo  Catalyst       DPS
# 445     yanfei     Yanfei  80       4    Pyro  Catalyst       DPS
# 446     yanfei     Yanfei  80       4    Pyro  Catalyst       DPS
#
#     Ascension Stat  Base HP  Base ATK  Base DEF  Ascension     Model Type  \
# 187        Geo DMG     5189       113       304        0.0    Tall Female
# 453       CRIT DMG     6839       177       388        0.0    Tall Female
# 182        Geo DMG      821        18        48        NaN    Tall Female
# 445       Pyro DMG     8289       213       520        0.0  Medium Female
# 446       Pyro DMG     8705       223       546        1.0  Medium Female
#
#         Region
# 187      Liyue
# 453  Mondstadt
# 182      Liyue
# 445      Liyue
# 446      Liyue

# %%
temp_df = df_growth[(df_growth.ID=='amber')]
sns.scatterplot(x='Lv', y='Base ATK', data=temp_df, hue='Ascension')
# Out:
# <AxesSubplot:xlabel='Lv', ylabel='Base ATK'>

# %%
X = np.array(temp_df['Lv']).reshape(1, -1).T
y = np.array(temp_df['Base ATK'])
reg = LinearRegression().fit(X, y)
reg.score(X, y)
# Out:
# 0.9886719066825643

# %% [markdown]
# ## Multiple Linear Regression

# %%
temp_df=temp_df[~temp_df['Ascension'].isna()]
X = np.array(temp_df[['Lv','Ascension']])
y = np.array(temp_df['Base ATK'])
reg = LinearRegression().fit(X, y)
reg.score(X, y)
# Out:
# 0.9936421239231009
